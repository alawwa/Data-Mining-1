# %%
import pandas as pd
data1=pd.read_csv("Tugas1.csv",sep=",")
data2=pd.read_csv("Tugas2.csv",sep=",") 

data_complete=pd.merge(data1,data2,on='ID')
data_complete.head()
# Out:
#    ID  Month  Sex  Head.L  Head.W  Neck.G  Length  Chest.G  Weight  Obs.No  \
# 0  39      7    1    10.0     5.0    15.0    45.0     23.0      65       1
# 1  41      7    2    11.0     6.5    20.0    47.5     24.0      70       1
# 2  41      7    2    11.0     6.5    17.0    57.0     27.0      74       2
# 3  41      7    2    11.0     6.5    20.5    59.5     38.0     142       3
# 4  41      7    2    11.0     6.5    18.0    62.0     31.0     121       4
#
#     Name
# 0  Allen
# 1  Berta
# 2  Berta
# 3  Berta
# 4  Berta

# %%
data_complete
# Out:
#       ID  Month  Sex  Head.L  Head.W  Neck.G  Length  Chest.G  Weight  Obs.No  \
# 0     39      7    1    10.0     5.0    15.0    45.0     23.0      65       1
# 1     41      7    2    11.0     6.5    20.0    47.5     24.0      70       1
# 2     41      7    2    11.0     6.5    17.0    57.0     27.0      74       2
# 3     41      7    2    11.0     6.5    20.5    59.5     38.0     142       3
# 4     41      7    2    11.0     6.5    18.0    62.0     31.0     121       4
# 5     41      8    2    12.0     6.0    20.0    47.5     24.0      70       1
# 6     41      8    2    12.0     6.0    17.0    57.0     27.0      74       2
# 7     41      8    2    12.0     6.0    20.5    59.5     38.0     142       3
# 8     41      8    2    12.0     6.0    18.0    62.0     31.0     121       4
# 9     41     11    2    12.5     5.0    20.0    47.5     24.0      70       1
# 10    41     11    2    12.5     5.0    17.0    57.0     27.0      74       2
# ...

# %%
import pandas as pd
df1 = pd.read_csv("Tugas3.csv",sep=",")
df2 = pd.read_csv("Tugas4.csv",sep=",")
frames = [df1,df2]
result = pd.concat(frames)

# %%
result
# Out:
#      ID  Month  Sex  Head.L  Head.W  Neck.G  Length  Chest.G  Weight  Obs.No  \
# 0    39      7    1    10.0     5.0    15.0    45.0     23.0      65       1
# 1    41      7    2    11.0     6.5    20.0    47.5     24.0      70       1
# 2    41      8    2    12.0     6.0    17.0    57.0     27.0      74       2
# 3    41     11    2    12.5     5.0    20.5    59.5     38.0     142       3
# 4    41      5    2    12.0     6.0    18.0    62.0     31.0     121       4
# 5    43      7    1    11.0     5.5    16.0    53.0     26.0      80       1
# 6    43      8    1    12.0     5.5    17.0    56.0     30.5     108       2
# 7    45      7    1    16.5     9.0    28.0    67.5     45.0     344       1
# 8    45      7    1    16.5     9.0    27.0    78.0     49.0     371       2
# 9    48      9    1    15.5     8.0    31.0    72.0     54.0     416       1
# 10   69     10    1    16.0     8.0    32.0    77.0     52.0     432       1
# ...
